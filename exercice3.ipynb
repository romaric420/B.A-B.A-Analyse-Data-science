# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = sns.load_dataset('anscombe')

df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
df["x"].hist()  
plt.show()

# %%
df["y"].hist()
plt.show()

# %%
plt.scatter(df["x"], df["y"], alpha=0.5, s=10, color='blue')
plt.show()

# %%
df['x'].describe()
# Out:
# count    44.000000
# mean      9.000000
# std       3.198837
# min       4.000000
# 25%       7.000000
# 50%       8.000000
# 75%      11.000000
# max      19.000000
# Name: x, dtype: float64

# %%
df["y"].describe()
# Out:
# count    44.000000
# mean      7.500682
# std       1.958925
# min       3.100000
# 25%       6.117500
# 50%       7.520000
# 75%       8.747500
# max      12.740000
# Name: y, dtype: float64

# %%
sns.boxenplot(x=df["x"])
plt.show()

# %%
sns.boxplot(y=df["y"])
# Out:
# <Axes: ylabel='y'>
